# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import geocoder
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 4
#       2 import folium
#       3 from folium.plugins import MarkerCluster
# ----> 4 import geocoder
#       5 import time
#
# ModuleNotFoundError: No module named 'geocoder'

# %%
#Load the Data
df = pd.read_csv('Resources/df_cleaned.csv')

# %%
df
# Out:
#         id  report_year agency_code agency_jurisdiction  population  \
# 0        1         1975     NM00101     Albuquerque, NM    286238.0
# 1        2         1975     TX22001       Arlington, TX    112478.0
# 2        3         1975     GAAPD00         Atlanta, GA    490584.0
# 3        4         1975     CO00101          Aurora, CO    116656.0
# 4        5         1975     TX22701          Austin, TX    300400.0
# ...    ...          ...         ...                 ...         ...
# 2683  2684         2014     AZ01003          Tucson, AZ    527328.0
# 2684  2685         2014     OK07205           Tulsa, OK    399556.0
# 2685  2686         2014     VA12800  Virginia Beach, VA    451102.0
# 2686  2687         2014     DCMPD00      Washington, DC    658893.0
# 2687  2688         2014     KS08703         Wichita, KS    387493.0
#
#       violent_crimes  homicides  rapes  assaults  robberies  months_reported  \
# ...

# %%
# Load the data
df = pd.read_csv('Resources/df_cleaned.csv')

# Initialize an empty map centered on the United States (or an average location)
map = folium.Map(location=[37.0902, -95.7129], zoom_start=5)  # Central USA coordinates

# Function to add markers for each year
def add_markers_by_year(year):
    # Filter the data for the specific year
    yearly_data = df[df['report_year'] == year]
    
    # Find the safest and most dangerous city based on crimes_percapita
    safest_city = yearly_data.loc[yearly_data['crimes_percapita'].idxmin()]
    most_dangerous_city = yearly_data.loc[yearly_data['crimes_percapita'].idxmax()]
    
    # Safest city marker
    folium.Marker(
        location=[safest_city['latitude'], safest_city['longitude']],
        popup=f"{safest_city['agency_jurisdiction']} - Safest City",
        tooltip="Safest City",
        icon=folium.Icon(color="blue")
    ).add_to(map)

    # Most dangerous city marker
    folium.Marker(
        location=[most_dangerous_city['latitude'], most_dangerous_city['longitude']],
        popup=f"{most_dangerous_city['agency_jurisdiction']} - Most Dangerous City",
        tooltip="Most Dangerous City",
        icon=folium.Icon(color="red")
    ).add_to(map)

# Loop through each unique year and add markers
for year in df['report_year'].unique():
    add_markers_by_year(year)

# Save or display the map
map.save("crime_map.html")
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 34
#      32 # Loop through each unique year and add markers
# ...
